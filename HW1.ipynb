# %% [markdown]
# <a href="https://colab.research.google.com/github/Prokudinsk/prokudinsk/blob/hw1/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Переменные**

# %%
price = 10
supply = "Карамель"
nuts = "Да"
amount = 5

# %% [markdown]
# **1. Функция**

# %%
class choc:
  def __init__(self, price:float, supply: str, nuts: bool, amount:int):
    self.price = price
    self.supply = supply
    self.nuts = nuts
    self.amount = amount

# %% [markdown]
# **2. Ошибка и цена**

# %%
if price > 0:
    print('Цена батончика:', price, 'руб.')
else:
    raise ValueError('ОШИБКА! Цена батончика должна быть больше нуля!')
# Out:
# Цена батончика: 10 руб.

# %% [markdown]
# **3. show_supply**

# %%
show_my_chocolate = choc(price, supply, nuts, amount)
if supply == 'Нет':
  print('Обычный шоколадный батончик')
else:
  print('Шоколадный батончик с добавкой :', supply)
# Out:
# Шоколадный батончик с добавкой : Карамель

# %% [markdown]
# **4. count nuts**

# %%
count_nuts = choc(price, supply, nuts, amount)
if nuts == 'Нет':
  print('Шоколадный батончик без орехов')
elif amount>=1:
  print('В шоколадном батончике содержится орехов: ', amount)
# Out:
# В шоколадном батончике содержится орехов:  5

# %% [markdown]
# **5. __Price__**

# %%
def __str__(self): # Преобразование к строке str(obj)
  return f'{self.price} {self.show_my_chocolateup} {self.nuts} {self.count_nuts}'
if price > 0:
    print('Цена батончика:', price, 'руб.')
else:
    raise ValueError('ОШИБКА! Цена батончика должна быть больше нуля!')
# Out:
# Цена батончика: 10 руб.
